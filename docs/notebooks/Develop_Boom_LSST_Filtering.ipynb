# %%
# plot training data

# %%
# all training lightcurves should be organized to peak on the same day, argument for data +/- peak when testing filter.

# %%
# how many objects does each section of the filter cut?

# %%
# confusion matrix
